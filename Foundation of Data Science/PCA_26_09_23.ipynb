# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\raval\Downloads\Wine.csv")
data.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline  Customer_Segment
# 0   3.92     1065                 1
# ...

# %%
data.isnull().sum()
# Out:
# Alcohol                 0
# Malic_Acid              0
# Ash                     0
# Ash_Alcanity            0
# Magnesium               0
# Total_Phenols           0
# Flavanoids              0
# Nonflavanoid_Phenols    0
# Proanthocyanins         0
# Color_Intensity         0
# Hue                     0
# OD280                   0
# Proline                 0
# Customer_Segment        0
# dtype: int64

# %%
df.corr()
# Out:
#                        Alcohol  Malic_Acid       Ash  Ash_Alcanity  Magnesium  \
# Alcohol               1.000000    0.094397  0.211545     -0.310235   0.270798
# Malic_Acid            0.094397    1.000000  0.164045      0.288500  -0.054575
# Ash                   0.211545    0.164045  1.000000      0.443367   0.286587
# Ash_Alcanity         -0.310235    0.288500  0.443367      1.000000  -0.083333
# Magnesium             0.270798   -0.054575  0.286587     -0.083333   1.000000
# Total_Phenols         0.289101   -0.335167  0.128980     -0.321113   0.214401
# Flavanoids            0.236815   -0.411007  0.115077     -0.351370   0.195784
# Nonflavanoid_Phenols -0.155929    0.292977  0.186230      0.361922  -0.256294
# Proanthocyanins       0.136698   -0.220746  0.009652     -0.197327   0.236441
# Color_Intensity       0.546364    0.248985  0.258887      0.018732   0.199950
# Hue                  -0.071747   -0.561296 -0.074667     -0.273955   0.055398
# ...

# %%
import seaborn as sns
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df["Customer_Segment"].dtypes
# Out:
# dtype('int64')

# %%
data["Customer_Segment"]=data["Customer_Segment"].astype('category')

# %%
data["Customer_Segment"].dtype
# Out:
# CategoricalDtype(categories=[1, 2, 3], ordered=False)

# %%
data.iloc[:,:-1]
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Alcohol               178 non-null    float64
#  1   Malic_Acid            178 non-null    float64
#  2   Ash                   178 non-null    float64
#  3   Ash_Alcanity          178 non-null    float64
#  4   Magnesium             178 non-null    int64
#  5   Total_Phenols         178 non-null    float64
#  6   Flavanoids            178 non-null    float64
#  7   Nonflavanoid_Phenols  178 non-null    float64
#  8   Proanthocyanins       178 non-null    float64
#  9   Color_Intensity       178 non-null    float64
#  10  Hue                   178 non-null    float64
#  11  OD280                 178 non-null    float64
#  12  Proline               178 non-null    int64
#  13  Customer_Segment      178 non-null    category
# dtypes: category(1), float64(11), int64(2)
# ...

# %%
import seaborn as sns
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),annot=True)
# Out:
# C:\Users\raval\AppData\Local\Temp\ipykernel_10208\1329581917.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True)
# <Axes: >

# %%
# import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# Load the dataset
# data = pd.read_csv(r'C:\Users\raval\Downloads\Wine.csv')

# Explore the dataset
print(data.head())

# # Define the features (X) and target variable (y)
# X = data.iloc[:, 1:].values  # Exclude the first column (Class)
# y = data.iloc[:, 0].values    # Target variable (Class)

X=data.iloc[:,:-1]
y=data["Customer_Segment"]

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# Feature scaling (optional but recommended for logistic regression)
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Train the logistic regression model
classifier = LogisticRegression(random_state=0)
classifier.fit(X_train, y_train)

# Make predictions on the test set
y_pred = classifier.predict(X_test)

# Evaluate the model
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: {:.2f}%".format(accuracy * 100))

classification_rep = classification_report(y_test, y_pred)
print("Classification Report:\n", classification_rep)

# # Plot the decision boundary (2D case, assuming only two features)
# if X_train.shape[1] == 2:
#     x_min, x_max = X_train[:, 0].min() - 1, X_train[:, 0].max() + 1
#     y_min, y_max = X_train[:, 1].min() - 1, X_train[:, 1].max() + 1
#     xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01),
#                          np.arange(y_min, y_max, 0.01))
#     Z = classifier.predict(np.c_[xx.ravel(), yy.ravel()])
#     Z = Z.reshape(xx.shape)

#     plt.contourf(xx, yy, Z, alpha=0.4)
#     plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, marker='o')
#     plt.title('Logistic Regression - Decision Boundary')
#     plt.xlabel('Feature 1')
#     plt.ylabel('Feature 2')
#     plt.show()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline Customer_Segment
# 0   3.92     1065                1
# ...

# %%
# import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Load the dataset
# data = pd.read_csv(r'C:\Users\raval\Downloads\Wine.csv')

# # Separate features (X) and the target variable (y)
# X = data.iloc[:, 1:].values  # Exclude the first column (Class)
# y = data.iloc[:, 0].values    # Target variable (Class)

# Standardize the features (mean=0, std=1)
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# Apply PCA
n_components = 2  # You can adjust the number of components as needed
pca = PCA(n_components=n_components)
X_pca = pca.fit_transform(X_std)

# Create a DataFrame for the PCA results
pca_df = pd.DataFrame(data=X_pca, columns=[f'PC{i+1}' for i in range(n_components)])

# Concatenate the PCA DataFrame with the target variable
pca_df['Class'] = y

# Plot the explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_
plt.bar(range(1, n_components + 1), explained_variance_ratio)
plt.xlabel('Principal Components')
plt.ylabel('Explained Variance Ratio')
plt.title('Explained Variance Ratio by Principal Component')
plt.show()

# Display the first few rows of the PCA DataFrame
print(pca_df.head())
# Out:
#         PC1       PC2 Class
# 0  3.316751 -1.443463     1
# 1  2.209465  0.333393     1
# 2  2.516740 -1.031151     1
# 3  3.757066 -2.756372     1
# 4  1.008908 -0.869831     1

# %%
pca.explained_variance_ratio_
# Out:
# array([0.36198848, 0.1920749 ])

# %%
# Create a scatter plot of the first two principal components
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis', edgecolor='k')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA 2D Projection')
plt.colorbar(label='Wine Class')
plt.show()

# %%
# import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Load the dataset
# data = pd.read_csv(r'C:\Users\raval\Downloads\Wine.csv')

# # Separate features (X) and the target variable (y)
# X = data.iloc[:, 1:].values  # Exclude the first column (Class)
# y = data.iloc[:, 0].values    # Target variable (Class)

# Standardize the features (mean=0, std=1)
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# Apply PCA
n_components2 = 6  # You can adjust the number of components as needed
pca2 = PCA(n_components=n_components2)
X_pca2 = pca2.fit_transform(X_std)

# Create a DataFrame for the PCA results
pca_df2 = pd.DataFrame(data=X_pca2, columns=[f'PC{i+1}' for i in range(n_components2)])

# Concatenate the PCA DataFrame with the target variable
pca_df2['Class'] = y

# Plot the explained variance ratio
explained_variance_ratio2 = pca2.explained_variance_ratio_
plt.bar(range(1, n_components2+1), explained_variance_ratio2)
plt.xlabel('Principal Components')
plt.ylabel('Explained Variance Ratio')
plt.title('Explained Variance Ratio by Principal Component')
plt.show()

# Display the first few rows of the PCA DataFrame
print(pca_df2.head())
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6 Class
# 0  3.316751 -1.443463 -0.165739 -0.215631  0.693043 -0.223880     1
# 1  2.209465  0.333393 -2.026457 -0.291358 -0.257655 -0.927120     1
# 2  2.516740 -1.031151  0.982819  0.724902 -0.251033  0.549276     1
# 3  3.757066 -2.756372 -0.176192  0.567983 -0.311842  0.114431     1
# 4  1.008908 -0.869831  2.026688 -0.409766  0.298458 -0.406520     1

# %%
explained_variance_ratio2
# Out:
# array([0.36198848, 0.1920749 , 0.11123631, 0.0706903 , 0.06563294,
#        0.04935823])

# %%
# Create a scatter plot of the first two principal components
plt.figure(figsize=(8, 6))
plt.scatter(pca_df2["PC1"], pca_df2["PC2"], c=y, cmap='viridis', edgecolor='k')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA 2D Projection')
plt.colorbar(label='Wine Class')
plt.show()

# %%
pca.explained_variance_ratio_
# Out:
# array([0.36198848, 0.1920749 , 0.11123631, 0.0706903 , 0.06563294,
#        0.04935823])

# %%
pca.explained_variance_
# Out:
# array([4.73243698, 2.51108093, 1.45424187, 0.92416587, 0.85804868,
#        0.64528221])

# %%
# import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Load the dataset
# data = pd.read_csv(r'C:\Users\raval\Downloads\Wine.csv')

# # Separate features (X) and the target variable (y)
# X = data.iloc[:, 1:].values  # Exclude the first column (Class)
# y = data.iloc[:, 0].values    # Target variable (Class)

# Standardize the features (mean=0, std=1)
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

l=[]
# Apply PCA
# n_components = 2  # You can adjust the number of components as needed
# Create a loop to generate PCA plots for different numbers of components
for n_components in range(1, 7):
    # Apply PCA
    pca = PCA(n_components=n_components)
    X_pca = pca.fit_transform(X_std)

# pca = PCA(n_components=n_components)
# X_pca = pca.fit_transform(X_std)

# Create a DataFrame for the PCA results
    pca_df = pd.DataFrame(data=X_pca, columns=[f'PC{i+1}' for i in range(n_components)])

# Concatenate the PCA DataFrame with the target variable
    pca_df['Class'] = y

# Plot the explained variance ratio
    explained_variance_ratio = pca.explained_variance_ratio_
    plt.bar(range(1, n_components + 1), explained_variance_ratio)
    plt.xlabel('Principal Components')
    plt.ylabel('Explained Variance Ratio')
    plt.title('Explained Variance Ratio by Principal Component')
    plt.show()
    l.append(explained_variance_ratio)

# Display the first few rows of the PCA DataFrame
    print(pca_df.head())
# Out:
#         PC1 Class
# 0  3.316751     1
# 1  2.209465     1
# 2  2.516740     1
# 3  3.757066     1
# 4  1.008908     1
#         PC1       PC2 Class
# 0  3.316751 -1.443463     1
# 1  2.209465  0.333393     1
# 2  2.516740 -1.031151     1
# 3  3.757066 -2.756372     1
# 4  1.008908 -0.869831     1
#         PC1       PC2       PC3 Class
# 0  3.316751 -1.443463 -0.165739     1
# 1  2.209465  0.333393 -2.026457     1
# 2  2.516740 -1.031151  0.982819     1
# 3  3.757066 -2.756372 -0.176192     1
# 4  1.008908 -0.869831  2.026688     1
#         PC1       PC2       PC3       PC4 Class
# 0  3.316751 -1.443463 -0.165739 -0.215631     1
# 1  2.209465  0.333393 -2.026457 -0.291358     1
# 2  2.516740 -1.031151  0.982819  0.724902     1
# 3  3.757066 -2.756372 -0.176192  0.567983     1
# 4  1.008908 -0.869831  2.026688 -0.409766     1
#         PC1       PC2       PC3       PC4       PC5 Class
# 0  3.316751 -1.443463 -0.165739 -0.215631  0.693043     1
# ...

# %%
l
# Out:
# [array([0.36198848]),
#  array([0.36198848, 0.1920749 ]),
#  array([0.36198848, 0.1920749 , 0.11123631]),
#  array([0.36198848, 0.1920749 , 0.11123631, 0.0706903 ]),
#  array([0.36198848, 0.1920749 , 0.11123631, 0.0706903 , 0.06563294]),
#  array([0.36198848, 0.1920749 , 0.11123631, 0.0706903 , 0.06563294,
#         0.04935823])]

# %%
0.36198848+0.1920749+0.11123631+0.0706903+0.06563294+0.04935823
# Out:
# 0.8509811599999999

# %%
a= pca.explained_variance_
import numpy as np
a= a/np.sum(a)

# %%
np.cumsum(a)
# Out:
# array([0.42537778, 0.65108772, 0.78180308, 0.86487225, 0.94199844,
#        1.        ])

# %%
# import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Load the dataset
# data = pd.read_csv(r'C:\Users\raval\Downloads\Wine.csv')

# # Separate features (X) and the target variable (y)
# X = data.iloc[:, 1:].values  # Exclude the first column (Class)
# y = data.iloc[:, 0].values    # Target variable (Class)

# Standardize the features (mean=0, std=1)
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

l=[]
# Apply PCA
# n_components = 2  # You can adjust the number of components as needed
# Create a loop to generate PCA plots for different numbers of components
for n_components in range(1, 8):
    # Apply PCA
    pca = PCA(n_components=n_components)
    X_pca = pca.fit_transform(X_std)

# pca = PCA(n_components=n_components)
# X_pca = pca.fit_transform(X_std)

# Create a DataFrame for the PCA results
    pca_df = pd.DataFrame(data=X_pca, columns=[f'PC{i+1}' for i in range(n_components)])

# Concatenate the PCA DataFrame with the target variable
    pca_df['Class'] = y

# Plot the explained variance ratio
    explained_variance_ratio = pca.explained_variance_ratio_
#     plt.bar(range(1, n_components + 1), explained_variance_ratio)
#     plt.xlabel('Principal Components')
#     plt.ylabel('Explained Variance Ratio')
#     plt.title('Explained Variance Ratio by Principal Component')
#     plt.show()
    l.append(explained_variance_ratio)

# Display the first few rows of the PCA DataFrame
    print(pca_df.head())
# Out:
#         PC1 Class
# 0  3.316751     1
# 1  2.209465     1
# 2  2.516740     1
# 3  3.757066     1
# 4  1.008908     1
#         PC1       PC2 Class
# 0  3.316751 -1.443463     1
# 1  2.209465  0.333393     1
# 2  2.516740 -1.031151     1
# 3  3.757066 -2.756372     1
# 4  1.008908 -0.869831     1
#         PC1       PC2       PC3 Class
# 0  3.316751 -1.443463 -0.165739     1
# 1  2.209465  0.333393 -2.026457     1
# 2  2.516740 -1.031151  0.982819     1
# 3  3.757066 -2.756372 -0.176192     1
# 4  1.008908 -0.869831  2.026688     1
#         PC1       PC2       PC3       PC4 Class
# 0  3.316751 -1.443463 -0.165739 -0.215631     1
# 1  2.209465  0.333393 -2.026457 -0.291358     1
# 2  2.516740 -1.031151  0.982819  0.724902     1
# 3  3.757066 -2.756372 -0.176192  0.567983     1
# 4  1.008908 -0.869831  2.026688 -0.409766     1
#         PC1       PC2       PC3       PC4       PC5 Class
# 0  3.316751 -1.443463 -0.165739 -0.215631  0.693043     1
# ...

# %%
l
# Out:
# [array([0.36198848]),
#  array([0.36198848, 0.1920749 ]),
#  array([0.36198848, 0.1920749 , 0.11123631]),
#  array([0.36198848, 0.1920749 , 0.11123631, 0.0706903 ]),
#  array([0.36198848, 0.1920749 , 0.11123631, 0.0706903 , 0.06563294]),
#  array([0.36198848, 0.1920749 , 0.11123631, 0.0706903 , 0.06563294,
#         0.04935823]),
#  array([0.36198848, 0.1920749 , 0.11123631, 0.0706903 , 0.06563294,
#         0.04935823, 0.04238679])]

# %%
# Calculate the sum for each array
sums = [np.sum(arr) for arr in l]

# Print the sums
for i, s in enumerate(sums, 1):
    print(f"Sum of array {i}: {s}")
# Out:
# Sum of array 1: 0.36198848099926323
# Sum of array 2: 0.5540633835693531
# Sum of array 3: 0.6652996889318528
# Sum of array 4: 0.7359899907589931
# Sum of array 5: 0.8016229275554791
# Sum of array 6: 0.8509811607477048
# Sum of array 7: 0.8933679539739379

# %%
# import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Load the dataset
# data = pd.read_csv(r'C:\Users\raval\Downloads\Wine.csv')

# # Separate features (X) and the target variable (y)
# X = data.iloc[:, 1:].values  # Exclude the first column (Class)
# y = data.iloc[:, 0].values    # Target variable (Class)

# Standardize the features (mean=0, std=1)
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

l2=[]
# Apply PCA
# n_components = 2  # You can adjust the number of components as needed
# Create a loop to generate PCA plots for different numbers of components
for n_components in range(1, 13):
    # Apply PCA
    pca = PCA(n_components=n_components)
    X_pca = pca.fit_transform(X_std)

# pca = PCA(n_components=n_components)
# X_pca = pca.fit_transform(X_std)

# Create a DataFrame for the PCA results
    pca_df = pd.DataFrame(data=X_pca, columns=[f'PC{i+1}' for i in range(n_components)])

# Concatenate the PCA DataFrame with the target variable
    pca_df['Class'] = y

# Plot the explained variance ratio
    explained_variance_ratio = pca.explained_variance_ratio_
#     plt.bar(range(1, n_components + 1), explained_variance_ratio)
#     plt.xlabel('Principal Components')
#     plt.ylabel('Explained Variance Ratio')
#     plt.title('Explained Variance Ratio by Principal Component')
#     plt.show()
    l2.append(explained_variance_ratio)

# Display the first few rows of the PCA DataFrame
    print(pca_df.head())
# Out:
#         PC1 Class
# 0  3.316751     1
# 1  2.209465     1
# 2  2.516740     1
# 3  3.757066     1
# 4  1.008908     1
#         PC1       PC2 Class
# 0  3.316751 -1.443463     1
# 1  2.209465  0.333393     1
# 2  2.516740 -1.031151     1
# 3  3.757066 -2.756372     1
# 4  1.008908 -0.869831     1
#         PC1       PC2       PC3 Class
# 0  3.316751 -1.443463 -0.165739     1
# 1  2.209465  0.333393 -2.026457     1
# 2  2.516740 -1.031151  0.982819     1
# 3  3.757066 -2.756372 -0.176192     1
# 4  1.008908 -0.869831  2.026688     1
#         PC1       PC2       PC3       PC4 Class
# 0  3.316751 -1.443463 -0.165739 -0.215631     1
# 1  2.209465  0.333393 -2.026457 -0.291358     1
# 2  2.516740 -1.031151  0.982819  0.724902     1
# 3  3.757066 -2.756372 -0.176192  0.567983     1
# 4  1.008908 -0.869831  2.026688 -0.409766     1
#         PC1       PC2       PC3       PC4       PC5 Class
# 0  3.316751 -1.443463 -0.165739 -0.215631  0.693043     1
# ...

# %%
# Calculate the sum for each array
sums = [np.sum(arr) for arr in l2]

# Print the sums
for i, s in enumerate(sums, 1):
#     print(f"Sum of array {i}: {s}")
    print(f"number of pc {i+1}: {s}")
# Out:
# number of pc 2: 0.36198848099926323
# number of pc 3: 0.5540633835693531
# number of pc 4: 0.6652996889318528
# number of pc 5: 0.7359899907589931
# number of pc 6: 0.8016229275554791
# number of pc 7: 0.8509811607477048
# number of pc 8: 0.8933679539739379
# number of pc 9: 0.9201754434577265
# number of pc 10: 0.9423969775056237
# number of pc 11: 0.9616971684450645
# number of pc 12: 0.9790655253449636
# number of pc 13: 0.9920478511010057
