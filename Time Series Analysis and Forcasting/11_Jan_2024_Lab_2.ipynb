# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\raval\Downloads\AusAntidiabeticDrug.csv")

# %%
df
# Out:
#              ds          y
# 0    1991-07-01   3.526591
# 1    1991-08-01   3.180891
# 2    1991-09-01   3.252221
# 3    1991-10-01   3.611003
# 4    1991-11-01   3.565869
# ..          ...        ...
# 199  2008-02-01  21.654285
# 200  2008-03-01  18.264945
# 201  2008-04-01  23.107677
# 202  2008-05-01  22.912510
# 203  2008-06-01  19.431740
#
# [204 rows x 2 columns]

# %%
# Convert 'ds' column to datetime format
df['ds'] = pd.to_datetime(df['ds'])

# Plotting seasonal graph
plt.figure(figsize=(12, 6))
plt.plot(df['ds'], df['y'], marker='o', linestyle='-', color='b')
plt.title('Seasonal Graph')
plt.xlabel('Date')
plt.ylabel('Value')
plt.grid(True)
plt.show()

# %%
import seaborn as sns

# %%
# Extract year from the 'ds' column
df['year'] = df['ds'].dt.year

# Create a seasonal plot using seaborn
plt.figure(figsize=(12, 6))
sns.lineplot(x='ds', y='y', hue='year', data=df, marker='o', palette='viridis')

# Adjust plot settings
plt.title('Yearly Seasonal Graph')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend(title='Year', loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)
plt.show()

# %%
# Extract year and month from the 'ds' column
df['year'] = df['ds'].dt.year
df['month'] = df['ds'].dt.month

# Create a line plot using seaborn
plt.figure(figsize=(12, 6))
sns.lineplot(x='month', y='y', hue='year', data=df, marker='o', palette='viridis')

# Adjust plot settings
plt.title('Yearly Seasonal Graph')
plt.xlabel('Month')
plt.ylabel('Value')
plt.legend(title='Year', loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)
plt.show()

# %%
df["year"] = df["ds"].dt.year
df["month"] = df["ds"].dt.strftime('%b')

plt.figure(figsize=(16,7))
sns.pointplot(x="month",y="y", hue="year", data=df,order=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug','Sep', 'Oct', 'Nov', 'Dec'])
plt.xlabel("month")
plt.ylabel("$ millions")
plt.title("AntiDiabetic Drug Sales in Australia Segmented on Year")
plt.legend(loc='upper right')

# %%
# # Convert 'time' column to datetime format
# df['ds'] = pd.to_datetime(df['time'], format='%Y.%f', errors='coerce') + pd.DateOffset(months=1)

# # Drop the original 'time' column
# df = df.drop(columns=['time'])

# # Create seasonal subplots
# g = sns.FacetGrid(df, col='ds', col_wrap=4, height=3, sharey=False)
# g.map(plt.scatter, 'X', 'value')

# # Calculate the mean of each month
# monthly_means = df.groupby('ds')['value'].mean()

# # Display mean values on each subplot
# for ax in g.axes:
#     month = ax.get_title()
#     mean_value = monthly_means.loc[month]
#     ax.axhline(y=mean_value, color='r', linestyle='--', label=f'Mean: {mean_value:.2f}')
#     ax.legend()

# # Adjust plot settings
# g.set_titles(col_template="{col_name}")
# plt.show()
