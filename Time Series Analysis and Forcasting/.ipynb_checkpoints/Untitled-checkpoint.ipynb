# %%
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

# Generate some data or use your own data
# For example, you can use a time series generated from the ARMA model
np.random.seed(42)
# Assuming a mean of 0 and a standard deviation of 1 for the errors
error = np.random.normal(loc=0, scale=1, size=100)
y = np.zeros(100)
y[0] = 16
for t in range(1, 100):
    y[t] = 16 + 0.6*y[t-1] + error[t] + 0.8*error[t-1]

# Plot ACF
fig, ax = plt.subplots(figsize=(12, 6))
sm.graphics.tsa.plot_acf(y, lags=24, ax=ax)
plt.title('Autocorrelation Function (ACF)')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.grid(True)
plt.axhline(y=0, color='black', linestyle='--', linewidth=0.5)
# Add 5% significance limits for the autocorrelations
plt.axhline(y=-1.96/np.sqrt(len(y)), color='gray', linestyle='--', linewidth=0.5)
plt.axhline(y=1.96/np.sqrt(len(y)), color='gray', linestyle='--', linewidth=0.5)
plt.xticks(np.arange(2, 26, 2))
plt.yticks(np.arange(-1, 1.2, 0.2))
plt.show()

# Plot PACF
fig, ax = plt.subplots(figsize=(12, 6))
sm.graphics.tsa.plot_pacf(y, lags=24, ax=ax)
plt.title('Partial Autocorrelation Function (PACF)')
plt.xlabel('Lag')
plt.ylabel('Partial Autocorrelation')
plt.grid(True)
plt.axhline(y=0, color='black', linestyle='--', linewidth=0.5)
# Add 5% significance limits for the autocorrelations
plt.axhline(y=-1.96/np.sqrt(len(y)), color='gray', linestyle='--', linewidth=0.5)
plt.axhline(y=1.96/np.sqrt(len(y)), color='gray', linestyle='--', linewidth=0.5)
plt.xticks(np.arange(2, 26, 2))
plt.yticks(np.arange(-1, 1.2, 0.2))
plt.show()
# Out:
# C:\Users\raval\AppData\Roaming\Python\Python311\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

# Generate some data or use your own data
np.random.seed(42)
error = np.random.normal(loc=0, scale=1, size=100)
y = np.zeros(100)
y[0] = 16
for t in range(1, 100):
    y[t] = 16 + 0.6*y[t-1] + error[t] + 0.8*error[t-1]

# Plot ACF
fig, ax = plt.subplots(figsize=(12, 6))
sm.graphics.tsa.plot_acf(y, lags=20, ax=ax)
plt.title('Autocorrelation Function (ACF)')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.grid(True)
plt.axhline(y=0, color='black', linestyle='--', linewidth=0.5)
plt.axhline(y=-1.96/np.sqrt(len(y)), color='gray', linestyle='--', linewidth=0.5)
plt.axhline(y=1.96/np.sqrt(len(y)), color='gray', linestyle='--', linewidth=0.5)
plt.xticks(np.arange(0, 21, 2))
plt.yticks(np.arange(-1, 1.2, 0.2))
plt.show()

# Plot PACF
fig, ax = plt.subplots(figsize=(12, 6))
sm.graphics.tsa.plot_pacf(y, lags=20, ax=ax, method='ols')  # Using 'ols' method for PACF
plt.title('Partial Autocorrelation Function (PACF)')
plt.xlabel('Lag')
plt.ylabel('Partial Autocorrelation')
plt.grid(True)
plt.axhline(y=0, color='black', linestyle='--', linewidth=0.5)
plt.axhline(y=-1.96/np.sqrt(len(y)), color='gray', linestyle='--', linewidth=0.5)
plt.axhline(y=1.96/np.sqrt(len(y)), color='gray', linestyle='--', linewidth=0.5)
plt.xticks(np.arange(0, 21, 2))
plt.yticks(np.arange(-1, 1.2, 0.2))
plt.show()

# %%
yt = 40 + 𝜀t + 0.7𝜀t−1 − 0.28𝜀t−2
yt = 8 + 0.8yt−1 + 𝜀t
yt = 4 + 0.4yt−1 + 0.5yt−2 + 𝜀t
yt = 16+0.6yt−1 + 𝜀t +0.8𝜀t−1
