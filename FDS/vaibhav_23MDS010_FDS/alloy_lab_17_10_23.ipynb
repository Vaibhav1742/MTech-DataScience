# %%
# import all the necessary libraries
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
df = pd.read_excel(r"C:\Users\raval\Downloads\Sample (1).xlsx")
df.head()
# Out:
#          Al        Co    Cr        Fe        Ni   Cu
# 0  0.000000  0.333333  0.00  0.333333  0.333333  0.0
# 1  0.076923  0.307692  0.00  0.307692  0.307692  0.0
# 2  0.142857  0.285714  0.00  0.285714  0.285714  0.0
# 3  0.200000  0.266667  0.00  0.266667  0.266667  0.0
# 4  0.000000  0.250000  0.25  0.250000  0.250000  0.0

# %%
# Your 'vec' dictionary
vec = {
    "Al": 3,
    "Co": 9,
    "Cr": 6,
    "Fe": 8,
    "Ni": 10,
    "Cu": 2,
}

# Define the electro negitivity as a dictionary
xi = {
    'Al': 1.61,
    'Co': 1.88,
    'Cr': 1.66,
    'Fe': 1.83,
    'Ni': 1.91,
    'Cu': 1.9
}

# Define the radius as a dictionary
ri = {
    'Al': 1.43,
    'Co': 1.25,
    'Cr': 1.28,
    'Fe': 1.26,
    'Ni': 1.24,
    'Cu': 1.28
}

# # Atomic radii for the mentioned elements (in nanometers)
# ri_nm = {
#     "Al": 0.143,
#     "Co": 0.125,
#     "Cr": 0.124,
#     "Fe": 0.126,
#     "Ni": 0.124,
#     "Cu": 0.128
# }

# %%
v = {}
x = {}
r = {}
col = ['Al', 'Co', 'Cr', 'Fe', 'Ni', 'Cu']

while True:
    total = 0
    for column_name in col:
        value = float(input(f"Enter the constant for column '{column_name}': "))
        v[column_name] = value
        total += value

    if 0.99 <= total <= 1.0:
        break
    else:
        print("The sum of constants must be between 0.99 and 1.0. Please re-enter the constants.")

# Calculate the 'vec' value
vec_value = sum(vec[column_name] * v[column_name] for column_name in col)

# Calculate the 'xi' value
# xi_value = sum(xi[column_name] * v[column_name] for column_name in col)

xbar = sum(v[element] for element in v)

# Calculate electronegativity difference (xi)
electronegativity_diff = sum(v[element] * electronegativity[element] for element in v) / xbar



# Calculate the 'ri' value
# ri_value = sum(ri[column_name] * v[column_name] for column_name in col)

# rbar = r1*co + r2*cr + r3*ni
# atomic_radi_diff= math.sqrt(([12(1)*(1-(11[i]/rbar))**2 for i in range(len(11))]))*100

# Calculate rbar
rbar = sum(r[element] * ri[element] for element in r)

# Calculate atomic radius difference
atomic_radius_diff = math.sqrt(sum((12 * r[element] * (1 - ri[element] / rbar)**2) for element in r)) * 100

# Print the resulting values
print("The 'vec' value is:", vec_value)
print("The 'xi' value is:", xi_value)
print("The 'ri' value is:", ri_value)

# %%
import math
# Define the vector constants as a dictionary
ri = {
    'Al': 1.43,
    'Co': 1.25,
    'Cr': 1.28,
    'Fe': 1.26,
    'Ni': 1.24,
    'Cu': 1.28
}

xi = {
    'Al': 1.61,
    'Co': 1.88,
    'Cr': 1.66,
    'Fe': 1.83,
    'Ni': 1.91,
    'Cu': 1.9
}

v = {}
x = {}
r = {}
col = ['Al', 'Co', 'Cr', 'Fe', 'Ni', 'Cu']

while True:
    total = 0
    for column_name in col:
        value = float(input(f"Enter the constant for column '{column_name}': "))
        v[column_name] = value
        total += value

    if 0.99 <= total <= 1.0:
        break
    else:
        print("The sum of constants must be between 0.99 and 1.0. Please re-enter the constants.")

# Calculate rbar
rbar = sum(v[element] * ri[element] for element in v)
# Calculate atomic radius difference
atomic_radius_diff = math.sqrt(sum((12 * v[element] * (1 - ri[element] / rbar)**2) for element in v)) * 100

xbar = sum(v[element] * xi[element] for element in v)

# Calculate electronegativity difference (xi)
electronegativity_diff = sum(v[element] * xi[element] for element in v) / xbar

print(f"xbar: {xbar}")
print(f"Electronegativity Difference (xi): {electronegativity_diff}")

print(f"rbar: {rbar}")
print(f"Atomic Radius Difference: {atomic_radius_diff}")
# Out:
# Enter the constant for column 'Al': 0
# Enter the constant for column 'Co': 0.33
# Enter the constant for column 'Cr': 0
# Enter the constant for column 'Fe': 0.33
# Enter the constant for column 'Ni': 0.34
# Enter the constant for column 'Cu': 0
# xbar: 1.8737
# Electronegativity Difference (xi): 1.0
# rbar: 1.2499
# Atomic Radius Difference: 2.2684036836311536

# %% [markdown]
# ### 19-10-23

# %%
# Calculate atomic radius difference
atomic_radius_diff = math.sqrt(sum((12 * r[element] * (1 - ri[element] / rbar)**2) for element in r)) * 100

# %%
for i in df.index:
    for j in df.iloc[i]:
        print(df)

#   sum=0;
#   for j in df.columns:
#     if(df[j][i]>0):
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0.0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 3
#       1 for i in df.index:
#       2     for j in df.iloc[i]:
# ----> 3         print(df[j])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 0.0

# %%
# xbar = sum(v[element] * xi[element] for element in v)

# Calculate xbar
xbar = df.dot(pd.Series(xi)).to_list()
# print(xbar)

# (df.sub(xbar, axis=0)) ** 2

# delta_xi = math.sqrt(sum((df * (xi - xbar)**2) for element in r)) * 100
for
    delta_xi = math.sqrt(((df * (pd.Series(xi) - xbar) ** 2).sum(axis=1)) * 100).to_list()
    dwlta_xi

# df_squared_diff = (pd.Series(xi) - xbar) ** 2
# delta_xi = math.sqrt((df * df_squared_diff).sum(axis=1) * 100)

print(delta_xi)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 13
#       4 xbar = df.dot(pd.Series(xi)).to_list()
#       5 # print(xbar)
#       6
#       7 # (df.sub(xbar, axis=0)) ** 2
#    (...)
#      10 # delta_xi = math.sqrt(((df * (pd.Series(xi) - xbar) ** 2).sum(axis=1)) * 100).to_list()
#      11 # dwlta_xi
# ---> 13 df_squared_diff = (pd.Series(xi) - xbar) ** 2
#      14 delta_xi = math.sqrt((df * df_squared_diff).sum(axis=1) * 100)
#      16 print(delta_xi)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:110, in OpsMixin.__sub__(self, other)
#     108 @unpack_zerodim_and_defer("__sub__")
#     109 def __sub__(self, other):
# --> 110     return self._arith_method(other, operator.sub)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6259, in Series._arith_method(self, other, op)
#    6257 def _arith_method(self, other, op):
#    6258     self, other = ops.align_method_SERIES(self, other)
# -> 6259     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\base.py:1325, in IndexOpsMixin._arith_method(self, other, op)
#    1322 rvalues = ensure_wrapped_if_datetimelike(rvalues)
#    1324 with np.errstate(all="ignore"):
# -> 1325     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1327 return self._construct_result(result, name=res_name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:226, in arithmetic_op(left, right, op)
#     222     _bool_arith_check(op, left, right)
#     224     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     225     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 226     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     228 return res_values
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:165, in _na_arithmetic_op(left, right, op, is_cmp)
#     162     func = partial(expressions.evaluate, op)
#     164 try:
# --> 165     result = func(left, right)
#     166 except TypeError:
#     167     if not is_cmp and (is_object_dtype(left.dtype) or is_object_dtype(right)):
#     168         # For object dtype, fallback to a masked operation (only operating
#     169         #  on the non-missing values)
#     170         # Don't do this for comparisons, as that will handle complex numbers
#     171         #  incorrectly, see GH#32047
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:241, in evaluate(op, a, b, use_numexpr)
#     238 if op_str is not None:
#     239     if use_numexpr:
#     240         # error: "None" not callable
# --> 241         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:129, in _evaluate_numexpr(op, op_str, a, b)
#     126     _store_test_result(result is not None)
#     128 if result is None:
# --> 129     result = _evaluate_standard(op, op_str, a, b)
#     131 return result
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:70, in _evaluate_standard(op, op_str, a, b)
#      68 if _TEST_MODE:
#      69     _store_test_result(False)
# ---> 70 return op(a, b)
#
# ValueError: operands could not be broadcast together with shapes (6,) (75,)

# %%
v = {}
x = {}
r = {}
col = ['Al', 'Co', 'Cr', 'Fe', 'Ni', 'Cu']

# %%
while True:
    total = 0
    for column_name in col:
        value = float(input(f"Enter the constant for column '{column_name}': "))
        v[column_name] = value
        total += value

    if total == 1.0:
        break
    else:
        print("The sum of constants must be between 0.99 and 1.0. Please re-enter the constants.")
# Out:
# Enter the constant for column 'Al': 0.33
# Enter the constant for column 'Co': 0.33
# Enter the constant for column 'Cr': 0.34
# Enter the constant for column 'Fe': 0
# Enter the constant for column 'Ni': 0
# Enter the constant for column 'Cu': 0

# %%
Smix=[] #-R sumation (ci log ci)
for i in df.index:
  sum=0;
  for j in df.columns:
    if(df[j][i]>0):
      sum = sum + (df[j][i]* np.log(df[j][i]))
  x = -8.3144598*sum
  Smix.append(x)

# %%
Smix
# Out:
# [9.134367709097084,
#  10.686517182639054,
#  11.239353681729584,
#  11.468070004939658,
#  11.526288736498014,
#  13.381606823529248,
#  13.381606823529248,
#  13.381606823529248,
#  13.381606823529248,
#  13.381606823529248,
#  11.526288736498014,
#  14.897512091332105,
#  13.145940421003386,
#  14.897512091332105,
#  13.381606823529248,
#  13.381606823529248,
#  13.381606823529248,
#  13.381606823529248,
#  13.381606823529248,
#  11.526288736498014,
#  11.526288736498014,
#  11.526288736498014,
#  9.134367709097084,
#  11.526288736498014,
#  13.381606823529248,
#  12.569171972766924,
#  13.145940421003386,
#  13.381606823529248,
#  14.897512091332105,
#  13.381606823529248,
#  13.145940421003386,
#  13.145940421003386,
#  13.915688860398712,
#  11.526288736498014,
#  12.911256210443373,
#  13.381606823529248,
#  11.747144413426762,
#  11.526288736498014,
#  13.381606823529248,
#  13.381606823529248,
#  13.381606823529248,
#  12.825994826506005,
#  13.381606823529248,
#  14.897512091332105,
#  12.796040407170631,
#  12.401552394657639,
#  12.401552394657639,
#  12.911256210443373,
#  12.825994826506005,
#  12.629836548310912,
#  12.629836548310912,
#  12.825994826506005,
#  11.526288736498014,
#  13.381606823529248,
#  11.526288736498014,
#  13.381606823529248,
#  11.36376437492682,
#  11.116080931016754,
#  13.381606823529248,
#  13.381606823529248,
#  13.238719285660244,
#  13.337700076211643,
#  13.033742694155631,
#  13.219007228078105,
#  13.328445769000467,
#  13.420058135988693,
#  13.372628894433536,
#  13.32022950643378,
#  12.825994826506005,
#  13.145940421003386,
#  13.308825328913093,
#  12.911256210443373,
#  12.911256210443373,
#  12.911256210443373,
#  12.911256210443373]

# %%
# df = df.drop(["vec"],axis=1)

# Atomic radii for the mentioned elements (in nanometers)

delta_atomic_radios = []

# Function to calculate Δ for a given composition
def calculate_delta(row):
    delta = 0
    for element, fraction in row.items():
        delta += abs(ri[element]) * fraction
    return delta

delta_atomic_radios = df.apply(calculate_delta, axis=1).tolist()
delta_atomic_radios

# Calculate Δ for each composition and add it as a new column
# df["delta"] = df.apply(calculate_delta, axis=1)

# Display the DataFrame with Δ values
# df
# Out:
# [1.2499999987500001,
#  1.26384615511,
#  1.27571428699,
#  1.2860000012500001,
#  1.2575,
#  1.292,
#  1.292,
#  1.292,
#  1.292,
#  1.292,
#  1.3025,
#  1.29000000258,
#  1.2766666653899998,
#  1.29000000258,
#  1.292,
#  1.292,
#  1.292,
#  1.292,
#  1.292,
#  1.2575,
#  1.2575,
#  1.2575,
#  1.25666666541,
#  1.2575,
#  1.292,
#  1.26571428578,
#  1.2766666653899998,
#  1.292,
#  1.29000000258,
#  1.262,
#  1.2766666653899998,
#  1.2766666653899998,
#  1.2703,
#  1.2575,
#  1.2826229495199999,
#  1.292,
#  1.2874,
#  1.3,
#  1.292,
#  1.262,
#  1.292,
#  1.26953488626,
#  1.262,
#  1.29000000258,
#  1.26875,
#  1.2584,
#  1.2584,
#  1.2826229495199999,
#  1.26953488626,
#  1.2754999999999999,
#  1.2754999999999999,
#  1.26953488626,
#  1.295,
#  1.292,
#  1.2575,
#  1.262,
#  1.19761904714,
#  1.1177777766599999,
#  1.292,
#  1.292,
#  1.279422,
#  1.2851,
#  1.273932,
#  1.2793139999999998,
#  1.284336,
#  1.3007840000000002,
#  1.295243,
#  1.300625,
#  1.26953488626,
#  1.2766666653899998,
#  1.2831914868099998,
#  1.2826229495199999,
#  1.2826229495199999,
#  1.2826229495199999,
#  1.2826229495199999]

# %%
delta_atomic_radios.clear()

# %%
d1 = {'Al':1.61, 'Co':1.88, 'Cr':1.66, 'Fe':1.83, 'Ni':1.91, 'Cu':1.9}
x_bar = []
for i in df.index:
  sum = 0
  for j in df.columns[:6]:
    var = df[j][i] * d1[j]
    sum = sum + var
  x_bar.append(sum)

delta_X = []
for i in df.index:
  sum = 0
  for j in df.columns[:6]:
    x1 = df[j][i]*np.square(d1[j]-x_bar[i])
    sum = sum + x1
  delta_X.append(np.sqrt(sum))

delta_X
# Out:
# [0.03299831643887304,
#  0.076999961615375,
#  0.09707981152300847,
#  0.10939022911615497,
#  0.09669539802906858,
#  0.12056533498481224,
#  0.12056533498481224,
#  0.12056533498481224,
#  0.12056533498481224,
#  0.12056533498481224,
#  0.12214233500306106,
#  0.11908213797172383,
#  0.11254628671795439,
#  0.11908213797172383,
#  0.12056533498481224,
#  0.12056533498481224,
#  0.12056533498481224,
#  0.12056533498481224,
#  0.12056533498481224,
#  0.09669539802906858,
#  0.09669539802906858,
#  0.09669539802906858,
#  0.1114550232596091,
#  0.09669539802906858,
#  0.12056533498481224,
#  0.10442586804235815,
#  0.11254628671795439,
#  0.12056533498481224,
#  0.11908213797172383,
#  0.09221713506718802,
#  0.11254628671795439,
#  0.11254628671795439,
#  0.10806479537758813,
#  0.09669539802906858,
#  0.12037520838328244,
#  0.12056533498481224,
#  0.1091459573232101,
#  0.13162446581088177,
#  0.12056533498481224,
#  0.09221713506718802,
#  0.12056533498481224,
#  0.10751633390630082,
#  0.09221713506718802,
#  0.11908213797172383,
#  0.0769053801759018,
#  0.12346273607854313,
#  0.12346273607854313,
#  0.12037520838328244,
#  0.10751633390630082,
#  0.10305818744767442,
#  0.10305818744767442,
#  0.10751633390630082,
#  0.1175531794550874,
#  0.12056533498481224,
#  0.09669539802906858,
#  0.09221713506718802,
#  0.12672095788082094,
#  0.21133191958423292,
#  0.12056533498481224,
#  0.12056533498481224,
#  0.11453683144074832,
#  0.11739267438814055,
#  0.1105604633343728,
#  0.11404746386044361,
#  0.11706009081662927,
#  0.12104592634832737,
#  0.12182808090091542,
#  0.12361735315076111,
#  0.10751633390630082,
#  0.11254628671795439,
#  0.11639289689780169,
#  0.12037520838328244,
#  0.12037520838328244,
#  0.12037520838328244,
#  0.12037520838328244]
