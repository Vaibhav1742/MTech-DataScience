# %%
import pandas as pd
import numpy as np

# %%
# load the data

# %%
df = pd.read_csv(r"C:\Users\raval\Downloads\bollywood.csv")

# %%
df
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS     Action
#
# ...

# %% [markdown]
# 1. how many records are present in the dataset? print the metadata information of dataset.

# %%
df.shape[0]
# Out:
# 149

# %%
df.shape[1]
# Out:
# 10

# %%
df.columns
# Out:
# Index(['SlNo', 'Release Date', 'MovieName', 'ReleaseTime', 'Genre', 'Budget',
#        'BoxOfficeCollection', 'YoutubeViews', 'YoutubeLikes',
#        'YoutubeDislikes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SlNo                 149 non-null    int64
#  1   Release Date         149 non-null    object
#  2   MovieName            149 non-null    object
#  3   ReleaseTime          149 non-null    object
#  4   Genre                149 non-null    object
#  5   Budget               149 non-null    int64
#  6   BoxOfficeCollection  149 non-null    float64
#  7   YoutubeViews         149 non-null    int64
#  8   YoutubeLikes         149 non-null    int64
#  9   YoutubeDislikes      149 non-null    int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 11.8+ KB

# %% [markdown]
# 2. which month of the year, maximum number of movie realeses are seen? (Note: Extract a new column called month from ReleaseDate column.) and do a barplot.

# %%
df["Release Date"] = pd.to_datetime(df["Release Date"])

# %%
df["month"] = pd.DatetimeIndex(df["Release Date"]).month

# %%
df["Release Date"].head()
# Out:
# 0   2014-04-18
# 1   2013-01-04
# 2   2014-07-18
# 3   2013-01-04
# 4   2014-07-04
# Name: Release Date, dtype: datetime64[ns]

# %%
# # df[df["Release Date"].format("mm")].head()
# df[df["Release Date"].format="mm"]

# %%
df
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS     Action
#
# ...

# %%
# bar plot

# %%
import matplotlib.pyplot as plt
df["month"].value_counts().sort_index().plot(kind="bar")
plt.xlabel("month")
plt.ylabel("number of movies")
plt.title("number of movies per month")
plt.show()

# %% [markdown]
# 3. Which are the top 10 movies with maximum return on investment (ROI)? Calculate return on investment (ROI) as (BoxOfficeCollection-Budgettivate Windows Budget.

# %%
# df["moth"] = df["Release Date"].

# %%
a =df["month"].groupby(df["YoutubeViews"].value_counts)

# %%
a

# %%
np.max(df["YoutubeViews"])
# Out:
# 23171067

# %%
(df["YoutubeViews"])==(np.max(df["YoutubeViews"]))
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 144    False
# 145    False
# 146    False
# 147    False
# 148    False
# Name: YoutubeViews, Length: 149, dtype: bool

# %%
df["month"][(df["YoutubeViews"])==(np.max(df["YoutubeViews"]))]
# Out:
# 119    11
# Name: month, dtype: int64

# %%
df["month"].value_counts()
# Out:
# 1     20
# 3     19
# 5     18
# 7     16
# 2     16
# 4     11
# 9     10
# 6     10
# 11    10
# 10     9
# 8      8
# 12     2
# Name: month, dtype: int64

# %%
a =df.groupby(df["month"]).sum()
# Out:
# C:\Users\raval\AppData\Local\Temp\ipykernel_15068\3794097637.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   a =df.groupby(df["month"]).sum()

# %%
df["month"].value_

# %%
a[a["YoutubeViews"]==(np.max(a["YoutubeViews"]))]
# Out:
#        SlNo  Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  \
# month
# 7      1225     359               847.51      63997745        158385
#
#        YoutubeDislikes
# month
# 7                22663

# %%
# Count the occurrences of each month
month_counts = df['month'].value_counts()

# Get the month with the maximum number of releases
max_month = month_counts.idxmax()

# %%
max_month
# Out:
# 1

# %%
df['Release Date'].dt.year
# Out:
# 0      2014
# 1      2013
# 2      2014
# 3      2013
# 4      2014
#        ...
# 144    2015
# 145    2015
# 146    2015
# 147    2015
# 148    2014
# Name: Release Date, Length: 149, dtype: int64

# %%
df['Release Date'].dt.month
# Out:
# 0      4
# 1      1
# 2      7
# 3      1
# 4      7
#       ..
# 144    2
# 145    3
# 146    3
# 147    3
# 148    5
# Name: Release Date, Length: 149, dtype: int64

# %%
a
# Out:
#        SlNo  Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  \
# month
# 1      1235     506               672.97      50532826        105598
# 2      1136     444               640.10      50179555        110023
# 3      1378     360               436.33      43903495         74280
# 4       759     265               467.50      30307762         76488
# 5      1276     424               744.98      36953839         70212
# 6       582     289               548.58      32827411         56425
# 7      1225     359               847.51      63997745        158385
# 8       695     460              1006.30      31142696         85952
# 9       890     281               737.10      35048814         89656
# 10      881     459               927.00      42665386        159981
# 11      936     365               473.60      53240279        123746
# 12      182     175               792.45      26550259         63007
#
#        YoutubeDislikes
# month
# 1                14242
# ...

# %%
df['year'] = df['Release Date'].dt.year
# df['month'] = df['Release Date'].dt.month

# %%
df
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1   2014-04-18                     2 States          LW    Romance
# 1       2   2013-01-04                 Table No. 21           N  Thriller
# 2       3   2014-07-18           Amit Sahni Ki List           N     Comedy
# 3       4   2013-01-04             Rajdhani Express           N     Drama
# 4       5   2014-07-04                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145   2015-02-27           Dum Laga Ke Haisha           N     Comedy
# 145   146   2015-03-13                         NH10           N   Thriller
# 146   147   2015-03-20  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148   2015-03-20                     Hunterrr           N     Comedy
# 148   149   2014-05-23                Kochadaiiyaan          HS     Action
#
# ...

# %%
b = df.groupby(["year","month"]).sum()
b
# Out:
# C:\Users\raval\AppData\Local\Temp\ipykernel_15068\1191509784.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   b = df.groupby(["year","month"]).sum()
#             SlNo  Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  \
# year month
# 2013 1        83     125               226.50      12552797         19256
#      2       177     142               253.85      12400373         27717
#      3       381     133               212.54       9152373          9642
#      4       308      87               239.50       9301482         20098
#      5       454     172               453.63      14274291         31359
#      6       454     109               231.78      11853955         24113
#      7       956     173               291.70      16085103         18346
# ...

# %%
b["YoutubeLikes"].max()
# Out:
# 140039

# %%
np.max(b["YoutubeViews"])
# Out:
# 47912642

# %%
# for i in b["year"].unique():
# #     print(i)
# #     b["YoutubeViews"]==(np.max(b["YoutubeViews"]))
#     b[b["YoutubeViews"]==(np.max(b["YoutubeViews"]))]

# %%
b[b["YoutubeViews"]==(np.max(b["YoutubeViews"]))]
# Out:
#             SlNo  Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  \
# year month
# 2014 7       269     186               555.81      47912642        140039
#
#             YoutubeDislikes
# year month
# 2014 7                19428

# %%
# b["year"].unique()
l=[]
for i in b.index:
#     print(i[0])
    l.append(i[0])
list(set(l))
# Out:
# [2013, 2014, 2015]

# %%
df.groupby('year')['YoutubeViews'].idxmax()
# Out:
# year
# 2013    119
# 2014     43
# 2015    137
# Name: YoutubeViews, dtype: int64

# %%
df.iloc[df.groupby('year')['YoutubeViews'].idxmax()]
# Out:
#      SlNo Release Date MovieName ReleaseTime     Genre  Budget  \
# 119   120   2013-11-01  Krrish 3          FS    Action     115
# 43     44   2014-07-25      Kick           N    Action     100
# 137   138   2015-01-16     Alone           N  Thriller      18
#
#      BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes  month  \
# 119                300.0      23171067         72070            11888     11
# 43                 377.0      18986221        101275            10066      7
# 137                 25.0       8788913         18907             2940      1
#
#      year
# 119  2013
# 43   2014
# 137  2015

# %%
# Group by year and find the row with the most YouTube views for each year
max_views_rows = df.groupby('year')['YoutubeViews'].idxmax()

# Filter the DataFrame to get the rows with most YouTube views for each year
max_views_data = df.loc[max_views_rows]

print(max_views_data)
# Out:
#      SlNo Release Date MovieName ReleaseTime     Genre  Budget  \
# 119   120   2013-11-01  Krrish 3          FS    Action     115
# 43     44   2014-07-25      Kick           N    Action     100
# 137   138   2015-01-16     Alone           N  Thriller      18
#
#      BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes  month  \
# 119                300.0      23171067         72070            11888     11
# 43                 377.0      18986221        101275            10066      7
# 137                 25.0       8788913         18907             2940      1
#
#      year
# 119  2013
# 43   2014
# 137  2015
