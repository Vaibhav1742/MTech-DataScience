# %% [markdown]
# import matplotlib and numpy library

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# creating two numpy array named x and y

# %%
x=np.array([10,70,23,33])
y=np.array([27,38,10,100])

# %%
# ploting (x,y) points 
plt.plot(x,y)
plt.show()

# %%
# plot x points
plt.plot(x)
plt.show()

# %%
# plot y points
plt.plot(y)

# %%
# mark points as * //we can also use =,+,-,^
plt.plot(x,y,"*")
plt.show()

# %%
# plot lines also with marker
plt.plot(x,y,marker="*")
plt.show()

# %%
# linestyle is used to give design to plot(connecting line)
plt.plot(x,y,marker="*",linestyle="--")
plt.show()

# %%
plt.plot(x,y,marker="*",linestyle=":")
plt.show()

# %%
# we can also use ls inplace of linestyle
plt.plot(x,y,marker="*",ls="-")
plt.show()

# %% [markdown]
# we can use color for give any color to line or marker (we can use red,blue,r,b or hexa-color code for the same)

# %%
plt.plot(x,y,marker="*",linestyle=":",color="#FF0000")
plt.show()

# %%
plt.plot(x,y,marker="*",linestyle=":",color="#00FF00")
plt.show()

# %%
plt.plot(x,y,marker="*",linestyle=":",color="#F812e6")
plt.show()

# %%
# we can use linewidth for giving customized width to lines
plt.plot(x,y,marker="+",color="#F812e6",linewidth=4)
plt.show()

# %%
plt.plot(x,color="#3F0983")
plt.plot(y,color="#fe4090")
plt.xlabel("x",color="#002212") #to give x label
plt.ylabel("y",color="#002212") #to give y label

# plt.title use for giving title to our figure

# fontstyle is used to give 'normal', 'italic', 'oblique'
# size is used to give font size for title
# loc is used to where the title should displayed
# fontfamily is used give style to text

plt.title("x and y graph",fontstyle="italic",color="#1288f0",loc="left",size=19)
# plt.title("x and y graph",color="#1288f0",loc="right",size=19,fontfamily="Times New Roman")
plt.show()

# %% [markdown]
# create a dict with all the parameter wich we are suppose to pass in plt.title ,
# we need to use fontdict for reducing same code again and again

# %%
d= {'color':'#1288f0',
    'size':19,
    'fontfamily':'Times New Roman'}

# %%
plt.figure(figsize=(5,6))
plt.plot(x,color="#3F0983")
plt.plot(y,color="#fe4090")
plt.xlabel("x",color="#002212",)
plt.ylabel("y",color="#002212")

# loc is not part of fontdict
plt.title("x and y graph",fontdict=d)

# plt.legend(["abc","xyz"],loc="lower right")
# plt.legend(["abc","xyz"],fontfamily='Times New Roman')

# bbox_to_anchor == for displaying lable out of the box (graph)
plt.legend(["abc","xyz"],fontsize=20,labelcolor="red",bbox_to_anchor=(0.8,1.4),ncol=2)

plt.show()

# %%
plt.figure(figsize=(5,5))
plt.plot(x,color="#3F0983")
plt.plot(y,color="#fe4090")
plt.xlabel("x",color="#002212",)
plt.ylabel("y",color="#002212")

# loc is not part of fontdict
plt.title("x and y graph",fontdict=d)

# plt.legend(["abc","xyz"],loc="lower right")
# plt.legend(["abc","xyz"],fontfamily='Times New Roman')

# we have to pass list of text (i.e.["abc","xyz"]) in plt.legend() for giving lables
# labelcolor == for giving color to lable with line color
plt.legend(["abc","xyz"],fontsize=20,labelcolor="linecolor",bbox_to_anchor=(0.8,1.4),ncol=2)

plt.show()

# %% [markdown]
# subplots are used display multiple plots(graphs) in one frame so that we can easily compare the graphs

# %%
plt.subplot(1,3,1)
plt.plot(x)

plt.subplot(1,3,2)
plt.plot(y)

plt.subplot(1,3,3)
plt.plot(x,y)

# %%
plt.subplot(3,1,1)
plt.plot(x)

plt.subplot(3,1,2)
plt.plot(y)

plt.subplot(3,1,3)
plt.plot(x,y)

# %% [markdown]
# create a == which follows normal distribution with mean 5 and stdanderd deviation of 1

# %%
a = np.random.normal(5,1,10000)
plt.plot(a) #plot the values
plt.show()

plt.hist(a) #plot the frequency of values
plt.hist(a,100) #plot the frequency of values with bins=100
plt.show()

# %%
# create a pie-chart 
plt.pie(a)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 3
#       1 # create a pie-chart
#       2 plt.pie(a)
# ----> 3 plt.show()
#
# File C:\python311\Lib\site-packages\matplotlib\pyplot.py:421, in show(*args, **kwargs)
#     377 """
#     378 Display all open figures.
#     379
#    (...)
#     418 explicitly there.
#     419 """
#     420 _warn_if_gui_out_of_main_thread()
# --> 421 return _get_backend_mod().show(*args, **kwargs)
#
# File C:\python311\Lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# ...

# %%
# create a bar chart
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
# create a pie chart for x (numpy array which we used in first in this notebook)
plt.pie(x)
plt.show()
